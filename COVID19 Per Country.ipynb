# %%
'''
Steps:
1. Import the data
2. Clean the data
3. Split the data into input and output sets. 'X' denotes input set 'y' denotes output set
4. Split the data into Training/Test Sets
5. Create a Model
6. Train the model
7. Make Predictions
8. Evaluate and improve
'''

import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import joblib
from sklearn import tree

covid_data = pd.read_csv('country_wise_latest.csv')

# Input data is Active cases, Cases confirmed over the past week, and 1 week change
X = covid_data.drop(columns = ['Confirmed', 'Deaths', 'Recovered', 'New deaths', 'Deaths / 100 Cases',
                              'Recovered / 100 Cases', '1 week % increase', 'WHO Region', 'New recovered'
                              , 'Deaths / 100 Recovered', "Country/Region", 'New cases', '1 week change'])
print(X)

# Output data is New cases per day
y = covid_data['New cases']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)


def load_model():
    joblib.load('covid-cases.joblib')
    print('Loaded')
    
    
def predict_and_score():
    predictions = model.predict(X_test)
    score = accuracy_score(y_test, predictions)
    print(f'Accuracy: {score * 100}%')
    print(predictions)
    print(y_test)
    
    
model = DecisionTreeClassifier()


def train():
    model.fit(X_train, y_train)

    
def save_model():
    joblib.dump(model, 'covid-cases.joblib')
    print('Saved')


train()
# save_model()
# load_model()
predict_and_score()
tree.export_graphviz(model, out_file='COVID_cases.dot', feature_names=['Active', 'Confirmed last week'],
                     class_names=sorted(y.unique()), label='all', rounded=True, filled=True)
# Out:
#      Active  Confirmed last week
# 0      9796                35526
# 1      1991                 4171
# 2      7973                23691
# 3        52                  884
# 4       667                  749
# ..      ...                  ...
# 182    6791                 8916
# 183       1                   10
# 184     375                 1619
# 185    1597                 3326
# 186    2126                 1713
#
# [187 rows x 2 columns]
# Accuracy: 26.31578947368421%
# [   0   47  152   13  368 1248    0   11    0  465   71   14    0    0
#  2434    3    0   39   65]
# 110       0
# 155      28
# 25      194
# 146      83
# 90      372
# 129    1146
# 68        1
# 114       1
# 141       0
# 7        73
# 131     104
# 144       2
# 100       0
# 94        0
# 35     2133
# 152       5
# 168       0
# 41      612
# 9        86
# Name: New cases, dtype: int64
