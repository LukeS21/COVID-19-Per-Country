# %%
'''
Steps:
1. Import the data
2. Clean the data
3. Split the data into input and output sets. 'X' denotes input set 'y' denotes output set
4. Split the data into Training/Test Sets
5. Create a Model
6. Train the model
7. Make Predictions
8. Evaluate and improve
'''

import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import joblib
from sklearn import tree

covid_data = pd.read_csv('country_wise_latest.csv')

# Input data is Active cases, Cases confirmed over the past week, and 1 week change
X = covid_data.drop(columns = ['Confirmed', 'Deaths', 'Recovered', 'New deaths', 'Deaths / 100 Cases',
                              'Recovered / 100 Cases', '1 week % increase', 'WHO Region', 'New recovered'
                              , 'Deaths / 100 Recovered', "Country/Region", 'New cases'])

# Output data is New cases per day
y = covid_data['New cases']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)


def load_model():
    joblib.load('covid-cases.joblib')
    print('Loaded')
    
    
def predict_and_score():
    predictions = model.predict(X_test)
    score = accuracy_score(y_test, predictions)
    print(f'Accuracy: {score * 100}%')
    print(predictions)
    print(y_test)
    
    
#model = DecisionTreeClassifier()


def train():
    model.fit(X_train, y_train)

    
def save_model():
    joblib.dump(model, 'covid-cases.joblib')
    print('Saved')


# train()
# save_model()
load_model()
predict_and_score()
# Out:
# Loaded
# Accuracy: 84.21052631578947%
# [   44     0  1592   445     0    67   469    28     0   109    15     0
#     68    24   213  4973   420   579    21    71    11   368    49    34
#     94     0    24    94   194  2133   372   496   594     0     0 16306
#      4   465]
# 160       44
# 24         0
# 13      2772
# 65       445
# 157        0
# 106       67
# 150      469
# 155       28
# 49         0
# 57       109
# 126       15
# 34         7
# 118       68
# 163       24
# 36       213
# 111     4973
# 52       420
# 58       579
# 139       58
# 185       71
# 86        11
# 8        368
# 102       49
# 67        34
# 99       158
# 166        0
# 104       24
# 1        117
# 25       194
# 35      2133
# 90       372
# 91       496
# 87       594
# 59         0
# 122        0
# 37     16306
# 164        4
# 93       483
# Name: New cases, dtype: int64
